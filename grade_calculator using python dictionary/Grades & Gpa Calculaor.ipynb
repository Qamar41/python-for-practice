# %% [markdown]
# # Grade Calculator

# %%
print('******************** Check out your Grade as well as quality points of your marks ********************* ')
quality_points_for_2={
    9: 0,
    10: 0,
    11: 0,
    12: 0,
    13: 0,
    14: 0,
    16:2 ,
    17:2.5 ,
    18: 3,
    19: 3.5,
    20: 4,
    21: 4.33,
    22: 4.67,
    23: 5,
    24: 5.33,
    25: 5.67,
    26: 6,
    27: 6.33,
    28: 6.67,
    29: 7,
    30: 7.33,
    31: 7.67,
    32: 8,
    33: 8,
    34: 8,
    35: 8,
    36: 8,
    37: 8,
    38: 8,
    39: 8,
    40:8,

}



quality_points_for_3 = {
    9:0,
    10:0,
    11:0,
    12:0,
    13:0,
    14:0,
    16:0,
    15:0,
    17:0,
    18:0,
    20:0,
    21:0,
    22:0,
    23:0,
    24:3,
    25:3.5,
    26:4,
    27:4.5,
    28:5,
    29:5.5,
    30:6,
    31:6.33,
    32:6.67,
    33:7,
    34:7.33,
    35:7.67,
    36:8,
    37:8.33,
    38:8.67,
    39:9,
    40:9.33,
    41:9.67,
    42:10,
    43:10.33,
    44:10.67,
    45:11,
    46:11.33,
    47:11.67,
    48:12,
    49:12,
    50:12,
    51:12,
    52:12,
    53:12,
    54:12,
    55:12,
    56:12,
    57:12,
    58:12,
    59:12,
    60:12

}
type=int(input('your course credit hours are : '))
if type==3:
    print('**********Note : you are finding your 3-credit hours Grade if you want to find out 2-credit hour Grade then plz restart this program***********' , end="\n\n")
    e=int(input('Enter Obtained Marks of Subject : '))
    g=quality_points_for_3[e]


    if g >=12:
        print(f"Your Grade is 'A'  & quality points are '{g}'")
    elif g>=9:
        print(f"Your Grade is 'B'  & quality points are '{g}'")
    elif g>=6:
        print(f"Your Grade is 'C'  & quality points are '{g}'")
    elif g>=3:
        print(f"Your Grade is 'D'  & quality points are '{g}'")
    else:
        print(f"Your Grade is 'F' ,quality points : '{g}' You have to try enroll this subject " ,end='\n\n' )
elif type==2:
    print(
        '**********Note : you are finding your 2-credit hours Grade if you want to find out 3-credit hour Grade then plz restart this program***********')
    e = int(input('Enter Obtained Marks of Subject : '))
    g = quality_points_for_2[e]


    if g >=8:
        print(f"Your Grade is 'A'  & quality points are '{g}'")
    elif g>=6:
        print(f"Your Grade is 'B'  & quality points are '{g}'")
    elif g>=4:
        print(f"Your Grade is 'C'  & quality points are '{g}'")
    elif g>=2:
        print(f"Your Grade is 'D'  & quality points are '{g}'")
    else:
        print(f"Your Grade is 'F' ,quality points : '{g}' & You have to try enroll this subject ")

else:
    print('oops! only 2 and 3-credit hour Grade calculator is availble so , please try again and only put 2 or 3: ')



print('@#@#@#@#@#@# \t\tThanks for Choosig us. Regards : (" B+ Team ") \t\t@#@#@#@#@#@#@#')
# Out:
# ******************** Check out your Grade as well as quality points of your marks *********************
# your course credit hours are : 2
# **********Note : you are finding your 2-credit hours Grade if you want to find out 3-credit hour Grade then plz restart this program***********

# %% [markdown]
# # Gpa Calculator

# %%
book1=int(input('Enter quality points of "Design and Analysis of Algorithm" :'))
book2=int(input('Enter quality points of "Financial Management" : '))
book3=int(input('Enter quality points of "Operational Research" :'))
book4=int(input('Enter quality points of "Web Programming" :'))
book5=int(input('Enter quality points of "Assembly Language" :'))
credit=int(input('Enter total credit hours : '))


gpa=(book1+book2+book3+book4+book5)/credit

print(f'Your Gpa of 5th semester is {gpa}')
